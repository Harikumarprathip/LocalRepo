# %% [markdown]
# #### Pyspark Basic Introduction

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\win10\anaconda3\envs\myenv\lib\site-packages (3.1.1)
# Requirement already satisfied: py4j==0.10.9 in c:\users\win10\anaconda3\envs\myenv\lib\site-packages (from pyspark) (0.10.9)

# %%
import pyspark

# %%
import pandas as pd
type(pd.read_csv('test1.csv'))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - 1) In order to work with pyspark we need to start a spark sesssion.

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Demo').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://host.docker.internal:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('test1.csv')

# %%
df_pyspark

# %%
#to seee entire data
df_pyspark.show()

# %%
df_pyspark=spark.read.option('header','true').csv('test1.csv')
# header=true, the first line will be treated as header not the data

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema() #Like df.info()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)

# %%
df_pyspark.head()

# %%
df_pyspark.show()
